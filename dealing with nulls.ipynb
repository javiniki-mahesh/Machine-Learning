# %% [markdown]
# # sklearn datasets

# %%
import sklearn

# %%
import pandas as pd
from pandas import DataFrame

# %%
price = pd.read_csv("D:\\complete machine learning course\\home-data-for-ml-course\\train.csv")
price
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
print(price.isna().sum().to_string())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
print(price['Fence'].info())
price['Fence'].fillna(value = 'not na',inplace= True)
price['Fence']
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: Fence
# Non-Null Count  Dtype
# --------------  -----
# 281 non-null    object
# dtypes: object(1)
# memory usage: 11.5+ KB
# None
# 0       not na
# 1       not na
# 2       not na
# 3       not na
# 4       not na
#          ...
# 1455    not na
# 1456     MnPrv
# 1457     GdPrv
# 1458    not na
# 1459    not na
# Name: Fence, Length: 1460, dtype: object

# %%
price
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
na_cols = price.columns[price.isna().any()]
na_cols
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'MiscFeature'],
#       dtype='object')

# %%
price[['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
       'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'MiscFeature']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotFrontage   1201 non-null   float64
#  1   Alley         91 non-null     object
#  2   MasVnrType    1452 non-null   object
#  3   MasVnrArea    1452 non-null   float64
#  4   BsmtQual      1423 non-null   object
#  5   BsmtCond      1423 non-null   object
#  6   BsmtExposure  1422 non-null   object
#  7   BsmtFinType1  1423 non-null   object
#  8   BsmtFinType2  1422 non-null   object
#  9   Electrical    1459 non-null   object
#  10  FireplaceQu   770 non-null    object
#  11  GarageType    1379 non-null   object
#  12  GarageYrBlt   1379 non-null   float64
#  13  GarageFinish  1379 non-null   object
#  14  GarageQual    1379 non-null   object
#  15  GarageCond    1379 non-null   object
#  16  PoolQC        7 non-null      object
#  17  MiscFeature   54 non-null     object
# ...

# %%
import numpy as np

# %%
notnull = price['Alley'].notnull()
notnull.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Alley, dtype: bool

# %%
notnull_values = price['Alley'][notnull]
print(notnull_values.head())
# Out:
# 21    Grvl
# 30    Pave
# 56    Pave
# 79    Grvl
# 87    Pave
# Name: Alley, dtype: object

# %%
notnull_values.value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
alley_mode = notnull_values.mode()[0]
alley_mode
# Out:
# 'Grvl'

# %%
price['Alley'].fillna(alley_mode, inplace = True)

# %%
print(price['Alley'].value_counts())
# in this case we mostly got Grvl
# so the result will skew towards Grvl
# for the next column we use different method to fill na values
# Out:
# Grvl    1419
# Pave      41
# Name: Alley, dtype: int64

# %%
# print(price.to_string())

# %%
price['PoolQC'].value_counts()
price['PoolQC'].fillna(method = 'ffill',inplace = True)
price['PoolQC'].fillna(method = 'bfill',inplace = True)
price['PoolQC']
# Out:
# 0       Ex
# 1       Ex
# 2       Ex
# 3       Ex
# 4       Ex
#         ..
# 1455    Gd
# 1456    Gd
# 1457    Gd
# 1458    Gd
# 1459    Gd
# Name: PoolQC, Length: 1460, dtype: object

# %%
price['PoolQC'].value_counts()
# Out:
# Ex    926
# Fa    397
# Gd    137
# Name: PoolQC, dtype: int64

# %%
# till now we have seen categorical values
# now we see continuous data

# %%
lot_mean = price['LotFrontage'].median()

# %%
price['LotFrontage'].mean()
# Out:
# 70.04995836802665

# %%
price['LotFrontage'].fillna(lot_mean,inplace = True)
price['LotFrontage'].isnull().sum() # 0 nan values : all are replaced
# Out:
# 0

# %%
max_nan = price.isna().sum(axis=1)
print(price[max_nan==12])
max_nan = max_nan.max()
print(max_nan)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave  Grvl      Reg
# 520    521         190       RL         60.0    10800   Pave  Grvl      Reg
# 533    534          20       RL         50.0     5000   Pave  Grvl      Reg
# 1011  1012          90       RL         75.0     9825   Pave  Grvl      Reg
# 1218  1219          50       RM         52.0     6240   Pave  Grvl      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC   Fence MiscFeature MiscVal  \
# 39           Lvl    AllPub  ...        0     Ex  not na         NaN       0
# 520          Lvl    AllPub  ...        0     Ex  not na         NaN       0
# 533          Low    AllPub  ...        0     Ex  not na         NaN       0
# 1011         Lvl    AllPub  ...        0     Fa  not na         NaN       0
# 1218         Lvl    AllPub  ...        0     Ex  not na         NaN       0
#
# ...

# %%
price.dropna(thresh = 70)
# total columns = 81
# max null columns = 12
# 81 - 12 = 69
# method to remove any rows that have less than 70 non-null values
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Grvl      Reg
# 1456  1457          20       RL         85.0    13175   Pave  Grvl      Reg
# 1457  1458          70       RL         66.0     9042   Pave  Grvl      Reg
# 1458  1459          20       RL         68.0     9717   Pave  Grvl      Reg
# 1459  1460          20       RL         75.0     9937   Pave  Grvl      Reg
#
# ...

# %%
# if I increase tresh more the no.of entries will decrease

# %%
price.dropna(thresh = 70, inplace = True)
# inplace to update original data frame

# %%
price
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Grvl      Reg
# 1456  1457          20       RL         85.0    13175   Pave  Grvl      Reg
# 1457  1458          70       RL         66.0     9042   Pave  Grvl      Reg
# 1458  1459          20       RL         68.0     9717   Pave  Grvl      Reg
# 1459  1460          20       RL         75.0     9937   Pave  Grvl      Reg
#
# ...
